# %%
import sys
sys.path.append('../')
import os

# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport log_plotter

from log_plotter import get_run_names, get_data_pth_events ,get_run_names_events, plot_smooth, plot_tag, plot_runs_and_tags, get_legend, plot_smooth_o1, get_run_names_events_tb

# %%
no_title = True
save_single = True
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42  # 3
matplotlib.rcParams['ps.fonttype'] = 42  # 3
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})

# %%
no_title = True
save_single = False
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 3
matplotlib.rcParams['ps.fonttype'] = 3
plt.rcParams.update({'font.size': 16})
markersoff = True
get_data_f = get_data_pth_events

# %% [markdown]
# ## Shared Params

# %%
get_data_f = get_data_pth_events
# plot_f = plt.plot
plot_f = plot_smooth_o1
logdir = '/h/iman/Code/dist-quantization/runs'
# lg_tags = ['bul-agg', 'bul-sel', 'aggregator', 'stochastic-num', 'attack', 'eps-reverse', 'stochastic-aggs_[0-9a-zA-Z]+(,[0-9a-zA-Z]+)*', 'resampling']  # , 'ngpu', 'bits', 'mul', 'bucket_size'
lg_tags = ['bul-agg', 'bul-sel', 'aggregator']  # , 'ngpu', 'bits', 'mul', 'bucket_size'


# orders = ['SuperSGD', 'ALQ-N', 'AMQ-N', 'Qinf', 'TRN', 'NUQ,p=0.5', 'SGD', 'ALQ', 'AMQ', 'ALQG-N', 'ALQG']
# lg_replace = [('resampling_', 'RESAMPLE='), ('stochastic-aggs_', 'SAGGS='), ('world-size_', 'workers='), ('num-byz_', 'BYZ='), ('stochastic-num_', 'NS='), ('aggregator_', 'AGG='), ('eps-reverse_', 'EPS='), ('bul-agg_', 'BA='), ('bul-sel_', 'BS='), ('aggregator_', 'AGG='), ('attack_', 'ATK=')]
lg_replace = [('num-byz_', 'BYZ='), ('stochastic-num_', 'NS='), ('aggregator_', 'AGG='), ('eps-reverse_', 'EPS='), ('bul-agg_', 'BA='), ('bul-sel_', 'BS='), ('aggregator_', 'AGG='), ('attack_', 'ATK='), ('comed', 'Comed'), ('krum', 'Krum'), ('stochastic', 'MixTailor'), ('omniscient', 'Omniscient')]
orders = ['AGG=Omniscient', 'AGG=MixTailor', 'AGG=Comed', 'AGG=Krum']
ylim = [None]*20

sep_h = False
save_single = True
ncolor = None
markeroff = True

# %% [markdown]
# # CIFAR10 bucket 16384

# %%
patterns = ['.*runs_comed_reverse_sgd/.*stoch.*aggregator_(stochastic|omniscient|krum|comed).*eps-reverse.*.\.1']
tags = ['Vloss', 'loss', 'Vacc', 'krum/select', 'bulyan/select']
logdir = '/h/iman/Code/dist-quantization/runs'
fig_name = 'figs_bsgd/mnist-sotch-krum.png'
plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)
# Out:
# ([], {})

# %%
patterns = ['.*runs_comed_reverse_sgd/.*aggregator_comed.*', '.*runs_comed_reverse_sgd/.*aggregator_omniscient.*eps-reverse_10.*']
tags = ['Vloss', 'loss', 'Vacc', 'krum/select', 'bulyan/select']
logdir = '/h/iman/Code/dist-quantization/runs'
fig_name = 'figs_bsgd/mnist-comed-krum.png'
plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)
# Out:
# ([], {})

# %% [markdown]
# ## CIFAR 10 DIfferent Aggregators

# %% [markdown]
# ### CoMed

# %%
patterns = ['.*runs_comed_cifar10_sgd/comeds.*niters.*50000.*aggregator_comed']
tags = ['Vloss', 'loss', 'Vacc', 'krum/select', 'bulyan/select']
logdir = '/h/iman/Code/dist-quantization/runs'
fig_name = 'figs_bsgd/mnist-rebuttal.png'
plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)
# Out:
# ([{'Vloss': {'Vloss': (array([    0.,   100.,   200.,   300.,   400.,   500.,   600.,   700.,
#               800.,   900.,  1000.,  1100.,  1200.,  1300.,  1400.,  1500.,
#              1600.,  1700.,  1800.,  1900.,  2000.,  2100.,  2200.,  2300.,
#              2400.,  2500.,  2600.,  2700.,  2800.,  2900.,  3000.,  3100.,
#              3200.,  3300.,  3400.,  3500.,  3600.,  3700.,  3800.,  3900.,
#              4000.,  4100.,  4200.,  4300.,  4400.,  4500.,  4600.,  4700.,
#              4800.,  4900.,  5000.,  5100.,  5200.,  5300.,  5400.,  5500.,
#              5600.,  5700.,  5800.,  5900.,  6000.,  6100.,  6200.,  6300.,
#              6400.,  6500.,  6600.,  6700.,  6800.,  6900.,  7000.,  7100.,
#              7200.,  7300.,  7400.,  7500.,  7600.,  7700.,  7800.,  7900.,
#              8000.,  8100.,  8200.,  8300.,  8400.,  8500.,  8600.,  8700.,
#              8800.,  8900.,  9000.,  9100.,  9200.,  9300.,  9400.,  9500.,
# ...

# %%
a = torch.tensor([[10, -1, 2],
                  [-2, 14, 3],
                  [6, 12, -1]], dtype=torch.float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-a9ad4216caca> in <module>
# ----> 1 a = torch.tensor([[10, -1, 2],
#       2                   [-2, 14, 3],
#       3                   [6, 12, -1]])
#
# NameError: name 'torch' is not defined

# %% [markdown]
# ### Krum

# %%
patterns = ['.*runs_krum_cifar10_sgd/.*']
tags = ['Vloss', 'loss', 'Vacc', 'krum/select', 'bulyan/select']
logdir = '/h/iman/Code/dist-quantization/runs'
fig_name = 'figs_bsgd/cifar10-krum.png'
plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)
# Out:
# ([{'Vloss': {'Vloss': (array([   0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,
#              900., 1000., 1100., 1200., 1300., 1400., 1500., 1600., 1700.,
#             1800., 1900., 2000., 2100., 2200., 2300., 2400., 2500., 2600.,
#             2700., 2800., 2900., 3000., 3100., 3200., 3300., 3400., 3500.,
#             3600., 3700., 3800., 3900., 4000., 4100., 4200., 4300., 4400.,
#             4500., 4600., 4700., 4800., 4900., 5000., 5100., 5200., 5300.,
#             5400., 5500., 5600., 5700., 5800., 5900., 6000., 6100., 6200.,
#             6300., 6400., 6500., 6600., 6700., 6800., 6900., 7000., 7100.,
#             7200., 7300., 7400., 7500., 7600., 7700., 7800., 7900., 8000.,
#             8100., 8200., 8300., 8400., 8500., 8600., 8700., 8800., 8900.,
#             9000., 9100., 9200., 9300., 9400., 9500., 9600., 9700., 9800.,
#             9900.]),
#      array([2.30291057, 2.0512538 , 1.92663836, 1.85508537, 1.78405476,
# ...

# %% [markdown]
# ### Bulyan

# %%
patterns = ['.*runs_bulyan_cifar10_sgd/.*aggregator_bulyan_.*bul-sel.*krum']
tags = ['Vloss', 'loss', 'Vacc', 'krum/select', 'bulyan/select']
logdir = '/h/iman/Code/dist-quantization/runs'
fig_name = 'figs_bsgd/cifar10-bulyan.png'
plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)
# Out:
# ([], {})

# %% [markdown]
# ## Stochastic

# %%
ylim = [[70, 100]]
learning_rates = ['0\.001']
# eps = ['5\.05', '0.5']
batch_size = ['50']
for bs in batch_size:
    for lr in learning_rates:
#         for ep in eps:
            patterns = [f'.*runs_stoch_adaptive_sgd/adaptive.*lr_{lr}.*batch-size_{bs}.*aggregator_(stochastic.stochastic-aggs_comed,krum,geomed,bulyan|krum|comed).*']
            patterns += [f'.*runs_stoch_adaptive_sgd/adaptive.*lr_{lr}.*batch-size_{bs}.*aggregator_(omniscient)']
            tags = ['Vacc']
            logdir = '/h/iman/Code/dist-quantization/runs'
            fig_name = f'figs_final/mnist-adaptive-lr-{lr}-bs-{bs}.png'
            plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)

# %%
ylim = [[0, 95]]
xlim = [0, 40000]
learning_rates = ['0\.001']
eps = ['0\.1', '10']
batch_size = ['80']
for bs in batch_size:
    for lr in learning_rates:
        for ep in eps:
            patterns = [f'.*runs_stoch_cifar10_sgd/.*stochcf.*lr_{lr}.*batch-size_{bs}.*aggregator_(stochastic.stochastic-aggs_comed,krum,geomed,bulyan|krum|comed).*eps-reverse_{ep}']
            patterns += [f'.*runs_stoch_cifar10_sgd/.*stochcf.*lr_{lr}.*batch-size_{bs}.*aggregator_(omniscient)']
            tags = ['Vacc']
            logdir = '/h/iman/Code/dist-quantization/runs'
            ep = ''.join(ep.split('\\'))
            lr = ''.join(lr.split('\\'))
            fig_name = f'figs_final/cifar10-stochastic-lr-{lr}-reverse-{ep}-bs-{bs}.png'
            print(plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=orders, xlim=xlim, no_title=no_title, acc_bits=None, markeroff=markeroff))
# Out:
# ([{'Vacc': {'Vacc': (array([    0.,   100.,   200.,   300.,   400.,   500.,   600.,   700.,
#          800.,   900.,  1000.,  1100.,  1200.,  1300.,  1400.,  1500.,
#         1600.,  1700.,  1800.,  1900.,  2000.,  2100.,  2200.,  2300.,
#         2400.,  2500.,  2600.,  2700.,  2800.,  2900.,  3000.,  3100.,
#         3200.,  3300.,  3400.,  3500.,  3600.,  3700.,  3800.,  3900.,
#         4000.,  4100.,  4200.,  4300.,  4400.,  4500.,  4600.,  4700.,
#         4800.,  4900.,  5000.,  5100.,  5200.,  5300.,  5400.,  5500.,
#         5600.,  5700.,  5800.,  5900.,  6000.,  6100.,  6200.,  6300.,
#         6400.,  6500.,  6600.,  6700.,  6800.,  6900.,  7000.,  7100.,
#         7200.,  7300.,  7400.,  7500.,  7600.,  7700.,  7800.,  7900.,
#         8000.,  8100.,  8200.,  8300.,  8400.,  8500.,  8600.,  8700.,
#         8800.,  8900.,  9000.,  9100.,  9200.,  9300.,  9400.,  9500.,
#         9600.,  9700.,  9800.,  9900., 10000., 10100., 10200., 10300.,
# ...

# %%
ylim = [[0, 90]]
learning_rates = ['0\.001']
eps = ['0\.1', '10']
batch_size = ['80']
for bs in batch_size:
    for lr in learning_rates:
        for ep in eps:
            patterns = [f'.*runs_stoch_cifar10_sampling/.*stochchf.*lr_{lr}.*batch-size_{bs}.*aggregator_(stochastic.stochastic-aggs_comed,krum,geomed,bulyan|krum|comed).*eps-reverse_{ep}']
            patterns += [f'.*runs_stoch_cifar10_sampling/.*stochchf.*lr_{lr}.*batch-size_{bs}.*aggregator_(omniscient)']
            tags = ['Vacc']
            logdir = '/h/iman/Code/dist-quantization/runs'
            fig_name = f'figs_final/cifar10-stochastic-h-lr-{lr}-reverse-{ep}-bs-{bs}.png'
            print(plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff))
# Out:
# ([], {})
# ([], {})

# %%
patterns = ['.*runs_stoch_mnist_sample/.*sample.*aggregator_comed.*']
tags = ['Vloss', 'loss', 'Vacc', 'krum/select', 'bulyan/select']
logdir = '/h/iman/Code/dist-quantization/runs'
fig_name = f'figs_bsgd/mnist-resampling.png'
plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)
# Out:
# ([{'Vloss': {'Vloss': (array([    0.,   100.,   200.,   300.,   400.,   500.,   600.,   700.,
#               800.,   900.,  1000.,  1100.,  1200.,  1300.,  1400.,  1500.,
#              1600.,  1700.,  1800.,  1900.,  2000.,  2100.,  2200.,  2300.,
#              2400.,  2500.,  2600.,  2700.,  2800.,  2900.,  3000.,  3100.,
#              3200.,  3300.,  3400.,  3500.,  3600.,  3700.,  3800.,  3900.,
#              4000.,  4100.,  4200.,  4300.,  4400.,  4500.,  4600.,  4700.,
#              4800.,  4900.,  5000.,  5100.,  5200.,  5300.,  5400.,  5500.,
#              5600.,  5700.,  5800.,  5900.,  6000.,  6100.,  6200.,  6300.,
#              6400.,  6500.,  6600.,  6700.,  6800.,  6900.,  7000.,  7100.,
#              7200.,  7300.,  7400.,  7500.,  7600.,  7700.,  7800.,  7900.,
#              8000.,  8100.,  8200.,  8300.,  8400.,  8500.,  8600.,  8700.,
#              8800.,  8900.,  9000.,  9100.,  9200.,  9300.,  9400.,  9500.,
# ...

# %%
x = 'stochc_072_lr_0.001,weight-decay_0.0001,niters_50000,workers_10,seed_1,batch-size_50,world-size_12,distributed_,aggregator_stochastic,stochastic-aggs_comed,geomed,fedavg,attack_epsilonreverse,eps-reverse_0.1,num-byz_2,local-rounds_1,agg-grad_'

# %% [markdown]
# ## MNIST Different Aggregators

# %%
patterns = ['.*runs_krum_mnist_sgd/.*']
tags = ['Vloss', 'loss', 'Vacc', 'krum/select', 'bulyan/select']
logdir = '/h/iman/Code/dist-quantization/runs'
fig_name = 'figs_bsgd/mnist-krum.png'
plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)
# Out:
# ()
# {'linestyle': '-', 'label': 'AGG=krum,ATK=epsilonreverse,EPS=10', 'color': 'blue', 'linewidth': 2}
# ()
# {'linestyle': '-', 'label': 'AGG=krum', 'color': 'darkred', 'linewidth': 2}
# ()
# {'linestyle': '-', 'label': 'AGG=krum,ATK=epsilonreverse,EPS=0.1', 'color': 'darkkhaki', 'linewidth': 2}
# ([{'Vloss': {'Vloss': (array([   0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,
#              900., 1000., 1100., 1200., 1300., 1400., 1500., 1600., 1700.,
#             1800., 1900., 2000., 2100., 2200., 2300., 2400., 2500., 2600.,
#             2700., 2800., 2900., 3000., 3100., 3200., 3300., 3400., 3500.,
#             3600., 3700., 3800., 3900., 4000., 4100., 4200., 4300., 4400.,
#             4500., 4600., 4700., 4800., 4900., 5000., 5100., 5200., 5300.,
#             5400., 5500., 5600., 5700., 5800., 5900., 6000., 6100., 6200.,
#             6300., 6400., 6500., 6600., 6700., 6800., 6900., 7000., 7100.,
# ...

# %%
patterns = ['.*runs_comed_mnist_sgd/.*']
tags = ['Vloss', 'loss', 'Vacc', 'krum/select', 'bulyan/select']
logdir = '/h/iman/Code/dist-quantization/runs'
fig_name = 'figs_bsgd/mnist-comed.png'
plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)
# Out:
# ([{'Vloss': {'Vloss': (array([   0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,
#              900., 1000., 1100., 1200., 1300., 1400., 1500., 1600., 1700.,
#             1800., 1900., 2000., 2100., 2200., 2300., 2400., 2500., 2600.,
#             2700., 2800., 2900., 3000., 3100., 3200., 3300., 3400., 3500.,
#             3600., 3700., 3800., 3900., 4000., 4100., 4200., 4300., 4400.,
#             4500., 4600., 4700., 4800., 4900., 5000., 5100., 5200., 5300.,
#             5400., 5500., 5600., 5700., 5800., 5900., 6000., 6100., 6200.,
#             6300., 6400., 6500., 6600., 6700., 6800., 6900., 7000., 7100.,
#             7200., 7300., 7400., 7500., 7600., 7700., 7800., 7900., 8000.,
#             8100., 8200., 8300., 8400., 8500., 8600., 8700., 8800., 8900.,
#             9000., 9100., 9200., 9300., 9400., 9500., 9600., 9700., 9800.,
#             9900.]),
#      array([2.29854798, 0.60285473, 0.36162961, 0.26575056, 0.21839431,
# ...

# %% [markdown]
# ### Stochastic

# %%
learning_rates = ['0\.001']
eps = ['0\.1', '10']
ylim = [[60, 100]]

batch_size = ['50']
for bs in batch_size:
    for lr in learning_rates:
        for ep in eps:
            patterns = [f'.*runs_stoch_mnist_sgd/.*stochmf.*lr_{lr}.*batch-size_{bs}.*.*eps-reverse_{ep}']
            patterns += [f'.*runs_stoch_mnist_sgd/.*stochmf.*lr_{lr}.*batch-size_{bs}.*aggregator_(omniscient)']

            tags = ['Vacc']
            logdir = '/h/iman/Code/dist-quantization/runs'
            fig_name = f'figs_final/mnist-stochastic-lr-{lr}-reverse-{ep}-bs-{bs}.png'
            plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=orders, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)

# %%
learning_rates = ['0\.001']
eps = ['0\.1', '10']
ylim = [[0, 100]]

batch_size = ['50']
for bs in batch_size:
    for lr in learning_rates:
        for ep in eps:
            patterns = [f'.*runs_stoch_mnist_sample/.*sotchmhf.*lr_{lr}.*batch-size_{bs}.*.*eps-reverse_{ep}']
            patterns += [f'.*runs_stoch_mnist_sample/.*sotchmhf.*lr_{lr}.*batch-size_{bs}.*aggregator_(omniscient)']

            tags = ['Vacc']
            logdir = '/h/iman/Code/dist-quantization/runs'
            fig_name = f'figs_final/mnist-h-stochastic-lr-{lr}-reverse-{ep}-bs-{bs}.png'
            plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=orders, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)

# %%
learning_rates = ['0\.001']
ylim = [[0, 100]]

batch_size = ['50']
for bs in batch_size:
    for lr in learning_rates:
        patterns = [f'.*runs_stoch_mnist_sample/.*sotchmhf.*lr_{lr}.*batch-size_{bs}.*world-size_10.*aggregator_(omniscient|krum|comed)']

        tags = ['Vacc']
        logdir = '/h/iman/Code/dist-quantization/runs'
        fig_name = f'figs_final/mnist-hi-stochastic-lr-{lr}-reverse-{ep}-bs-{bs}.png'
        plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=orders, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)

# %%
learning_rates = ['0\.001']#, '0\.001']
eps = ['0\.1', '10']#, '10']
batch_size = ['50']
resample = ['20', '2']
for bs in batch_size:
    for lr in learning_rates:
        for r in resample:
            for ep in eps:
                patterns = [f'.*runs_stoch_mnist_sample/.*msample.*lr_{lr}.*resampling_{r},seed_1,batch-size_{bs}.*eps-reverse_{ep}']
                tags = ['Vloss', 'loss', 'Vacc', 'krum/select', 'bulyan/select']
                logdir = '/h/iman/Code/dist-quantization/runs'
                fig_name = f'figs_bsgd/mnist-hetr-lr-{lr}-reverse-{ep}-bs-{bs}-r-{r}.png'
                plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)
# Out:
# ()
# {'linestyle': '-', 'label': 'AGG=stochastic,ATK=epsilonreverse,EPS=0.1,workers=12,SAGGS=krum,geomed,attackRESAMPLE=20', 'color': 'blue', 'linewidth': 2}
# ()
# {'linestyle': '-', 'label': 'AGG=stochastic,ATK=epsilonreverse,EPS=0.1,workers=12,SAGGS=comed,bulyan,attackRESAMPLE=20', 'color': 'darkred', 'linewidth': 2}
# ()
# {'linestyle': '-', 'label': 'AGG=stochastic,ATK=epsilonreverse,EPS=0.1,workers=12,SAGGS=krum,geomed,bulyan,attackRESAMPLE=20', 'color': 'darkkhaki', 'linewidth': 2}
# ()
# {'linestyle': '-', 'label': 'AGG=stochastic,ATK=epsilonreverse,EPS=0.1,workers=12,SAGGS=comed,krum,geomed,bulyan,attackRESAMPLE=20', 'color': 'darkblue', 'linewidth': 2}
# ()
# {'linestyle': '--', 'label': 'AGG=stochastic,ATK=epsilonreverse,EPS=0.1,workers=12,SAGGS=comed,krum,attackRESAMPLE=20', 'color': 'blue', 'linewidth': 2}
# ()
# ...

# %%
patterns = ['.*runs_bulyan_mnist_sgd/.*aggregator_bulyan.*bul-agg.*comed.*bul-sel.*krum']
tags = ['Vloss', 'loss', 'Vacc', 'krum/select', 'bulyan/select']
logdir = '/h/iman/Code/dist-quantization/runs'
fig_name = 'figs_bsgd/mnist-bulyan.png'
plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tags, fig_name, lg_tags, ylim, sep_h=sep_h, ncolor=ncolor, lg_replace=lg_replace, save_single=save_single, vlines=None, color_order=None, xlim=None, no_title=no_title, acc_bits=None, markeroff=markeroff)
# Out:
# ()
# {'linestyle': '-', 'label': 'BA=comed,BS=krum,AGG=bulyan,ATK=epsilonreverse,EPS=10', 'color': 'blue', 'linewidth': 2}
# ()
# {'linestyle': '-', 'label': 'BA=comed,BS=krum,AGG=bulyan,ATK=epsilonreverse,EPS=0.1', 'color': 'orangered', 'linewidth': 2}
# ()
# {'linestyle': '-', 'label': 'BA=comed,BS=krum,AGG=bulyan', 'color': 'darkred', 'linewidth': 2}
# ()
# {'linestyle': '-', 'label': 'BA=comed,BS=krum,AGG=bulyan,ATK=epsilonreverse,EPS=10', 'color': 'blue', 'linewidth': 2}
# ()
# {'linestyle': '-', 'label': 'BA=comed,BS=krum,AGG=bulyan,ATK=epsilonreverse,EPS=0.1', 'color': 'orangered', 'linewidth': 2}
# ()
# {'linestyle': '-', 'label': 'BA=comed,BS=krum,AGG=bulyan', 'color': 'darkred', 'linewidth': 2}
# ([{'Vloss': {'Vloss': (array([   0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,
#              900., 1000., 1100., 1200., 1300., 1400., 1500., 1600., 1700.,
#             1800., 1900., 2000., 2100., 2200., 2300., 2400., 2500., 2600.,
# ...

# %%
def plot_runs_and_tags(get_data_f, plot_f, logdir, patterns, tag_names,
                       fig_name, lg_tags, ylim, batch_size=None, sep_h=True,
                       ncolor=None, save_single=False, lg_replace=[],
                       xlim=None, acc_bits=None, markeroff=True,
                       no_title=False, vlines=None, color_order=None):
    if len(data) == 0:
        return data, run_name†sTd
    num = len(tag_names)
    height = (num + 1) // 2
    width = 2 if num > 1 else 1
    if not save_single:
        fig = plt.figure(figsize=(7 * width, 4 * height))
        fig.subplots(height, width)
    else:
        plt.figure(figsize=(7, 4))
    plt.tight_layout(pad=1., w_pad=3., h_pad=3.0)
    fi = 1
    if save_single:
        fig_dir = fig_name[:fig_name.rfind('.')]
        try:
            os.makedirs(fig_dir)
        except os.error:
            pass
    for i in range(len(tag_names)):
        yl = ylim[i]
        if not isinstance(yl, list) and yl is not None:
            yl = ylim
        if not save_single:
            plt.subplot(height, width, fi)
        plot_tag(data, plot_f, list(run_names), tag_names[i], lg_tags, yl,
                 ncolor=ncolor, lg_replace=lg_replace, no_title=no_title, points=None, vlines=vlines, xlim=xlim, orders=color_order,
                 acc_bits=acc_bits, markeroff=markeroff)
        if save_single:
            plt.savefig('%s/%s-lo.pdf' % (fig_dir, tag_names[i]),
                        dpi=100, bbox_inches='tight')
                    
            ax = plt.gca()

            handles, labels = ax.get_legend_handles_labels()
            if color_order:
                norders = []
                for order in color_order:
                    if order in labels:
                        norders.append(order)

                order = []

                for label in labels:
                    order.append(norders.index(label))

                nlabels = np.arange(len(labels)).tolist()
                nhandles = np.arange(len(handles)).tolist()
                for idx, label, handle in zip(order, labels, handles):
                    nlabels[idx] = label
                    nhandles[idx] = handle
                handles = nhandles
                labels = nlabels

            plt.legend(handles, labels, prop={'size': 12})

            plt.savefig('%s/%s-li.pdf' % (fig_dir, tag_names[i]),
                        dpi=100, bbox_inches='tight')

            ax.get_legend().remove()
            plt.savefig('%s/%s.pdf' % (fig_dir, tag_names[i]),
                        dpi=100, bbox_inches='tight')

            plt.figure(figsize=(7, 4))
        fi += 1
    plt.savefig(fig_name, dpi=100, bbox_inches='tight')

# %%
len(data)
